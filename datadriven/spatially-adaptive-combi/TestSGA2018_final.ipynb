# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sys import path
#path.append('../../../src/')
#path.append('../../../src/tools')
import numpy as np
#from numpy import *
import scipy as sp
from spatiallyAdaptiveExtendSplit import *
from spatiallyAdaptiveSplit import *

from PerformTestCase import *
from Function import *
from ErrorCalculator import *
import math

# %% [markdown]
# a = 0
# b = 1
# dim = 10
# midpoints = np.ones(dim) * 0.75
# coefficients = np.array([ 10**0 * (d+1) for d in range(dim)])
# f = Function2Jakeman(midpoints,coefficients)
# f.plot(np.ones(dim)*a,np.ones(dim)*b)
# errorOperator=ErrorCalculatorAnalytic()
# grid=TrapezoidalGrid(True)
# adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
# adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
# #adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,grid,noInitialSplitting=True, topDiagIncreaseCoarsening=True)
# adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid,noInitialSplitting=False, topDiagIncreaseCoarsening=True)
#
# #adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
# algorithmArray = [(adaptiveCombiInstanceExtend2,1,2,'Extend scheme min=1 max=2')]
# performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,4,dim,6,grid,1,5)

# %% [markdown]
# Test Corner Small

# %%
a = 0
b = 1
dim = 2
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b, "functionCornerSmall.pdf")

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=ClenshawCurtisGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,4,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed Scheme')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,11,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00195884176762
# combiintegral: -0.00195767026972
# Current error: 0.00195884176769
# Number of refinements 0
# time spent in case
#  1 0.7488973140716553
# time spent in case
#  2 0.06212592124938965
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00195884176762
# combiintegral: -0.00195767026972
# Current error: 0.00195884176769
# Refining position 31
# Finished refinement
# max error:
#  4.97651900926e-05
# combiintegral: -4.87789636115e-05
# Current error: 4.9950461582e-05
# Number of refinements 1
# time spent in case
#  3 1.426955223083496
# time spent in case
#  4 0.1201469898223877
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=ClenshawCurtisGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed Scheme')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,11,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00195884176762
# combiintegral: -0.00195767026972
# Current error: 0.00195884176769
# Number of refinements 0
# time spent in case
#  1 0.7105100154876709
# time spent in case
#  2 0.06087374687194824
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00195884176762
# combiintegral: -0.00195767026972
# Current error: 0.00195884176769
# Refining position 31
# Finished refinement
# max error:
#  4.97651900926e-05
# combiintegral: -4.87789636115e-05
# Current error: 4.9950461582e-05
# Number of refinements 1
# time spent in case
#  3 1.371082067489624
# time spent in case
#  4 0.11542510986328125
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=TrapezoidalGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,4,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed Scheme')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,10,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00125929041689
# combiintegral: -0.00125811891897
# Current error: 0.00125929041694
# Number of refinements 0
# time spent in case
#  1 0.38389158248901367
# time spent in case
#  2 0.05489349365234375
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00125929041689
# combiintegral: -0.00125811891897
# Current error: 0.00125929041694
# Refining position 31
# Finished refinement
# max error:
#  3.10289374178e-05
# combiintegral: -2.99756070449e-05
# Current error: 3.11471050154e-05
# Number of refinements 1
# time spent in case
#  3 0.809882640838623
# time spent in case
#  4 0.1088714599609375
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=TrapezoidalGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,3,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed Scheme')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,10,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.1714979705e-06
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00125929041689
# combiintegral: -0.00125811891897
# Current error: 0.00125929041694
# Number of refinements 0
# time spent in case
#  1 0.398207426071167
# time spent in case
#  2 0.05623435974121094
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00125929041689
# combiintegral: -0.00125811891897
# Current error: 0.00125929041694
# Refining position 31
# Finished refinement
# max error:
#  3.10289374178e-05
# combiintegral: -2.99756070449e-05
# Current error: 3.11471050154e-05
# Number of refinements 1
# time spent in case
#  3 0.8495974540710449
# time spent in case
#  4 0.11443209648132324
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
montecarloNumPoints = []
montecarloError = []
for i in range(8):
    analyticSolution = f.getAnalyticSolutionIntegral(np.ones(dim)* a, np.ones(dim)* b)
    integral = montecarlo(f,10**i,dim)
    montecarloError.append(abs(integral - analyticSolution)/analyticSolution)
    montecarloNumPoints.append(10**i)
    print(10**i,abs(integral - analyticSolution)/analyticSolution)
print("montecarloNumPoints =",montecarloNumPoints)
print("montecarloError =",montecarloError)
# Out:
# 1 1.0
# 10 1.0
# 100 1.0
# 1000 1.0
# 10000
#  0.988917386671
# 100000
#  0.976749791119
# 1000000
#  0.0104052871448
# 10000000
#  0.138151957937
# montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
# montecarloError = [1.0, 1.0, 1.0, 0.99999999999999978, 0.98891738667099216, 0.97674979111946592, 0.010405287144789747, 0.1381519579371219]

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
montecarloError = [1.0, 1.0, 1.0, 0.99999999999999978, 0.98891738667099216, 0.97674979111946592, 0.010405287144789747, 0.1381519579371219]
numPointsSGpp=[1053, 2943, 7638, 17952, 40374, 87868, 188573, 317346, 457813, 600332, 741197, 880989, 1019897, 1154856, 1289512, 1423593, 1555643, 1688833, 1820526, 1949850, 2079732, 2209623, 2339152, 2467869, 2594857, 2722524, 2849803, 2976616, 3104244, 3230324, 3355709, 3479131, 3605554, 3731858, 3856372, 3982564, 4107690, 4230942, 4353640, 4476414, 4600060, 4724659, 4849474, 4973379, 5094290, 5216511, 5337523, 5462469, 5584947, 5705403, 5825886, 5944502, 6069280, 6191097, 6312202, 6434704, 6555350, 6675812, 6797740, 6917930, 7037547, 7158302, 7278359, 7397368, 7517150, 7635507, 7751432, 7872343, 7994991, 8114704, 8234073, 8356371, 8477212, 8595690, 8712999, 8832421, 8952347, 9070719, 9188905, 9308545, 9427040, 9543093, 9660341, 9775358, 9894294, 10011698, 10127909, 10242556, 10361758, 10483721, 10601738, 10717254, 10836863, 10958013, 11075866, 11194241, 11311081, 11426413, 11542447, 11659823, 11776861] 
errorSGpp=[1074.94, 51.8821, 511.182, 84.1751, 137.613, 53.4247, 11.9575, 11.6251, 2.36066, 0.0334696, 0.786669, 0.159068, 0.393117, 0.167582, 0.310112, 0.104584, 0.342423, 0.242027, 0.131912, 0.0391875, 0.0964924, 0.127022, 0.120085, 0.0603575, 0.0388056, 0.0534889, 0.0755591, 0.0847425, 0.0850172, 0.0692518, 0.0547365, 0.0458136, 0.0496575, 0.0499369, 0.0594748, 0.0407324, 0.0527178, 0.0377936, 0.0410
[1053, 3753, 12033, 36033, 102785, 282625, 754945, 1969665] 
standard1FEErrorCC = [256.30850344842281, 343.50348207902056, 294.10168251158342, 179.09098063884301, 81.990589634414007, 29.066114862276645, 8.0717330027043772, 1.7486374402258777]
standard1NumPointsCC = [2268, 12663, 55098, 206358, 698885, 2202350, 6574845, 18820515] 
standard1ErrorCC = [256.30850344842281, 343.50348207902056, 294.10168251158342, 179.09098063884301, 81.990589634414007, 29.066114862276645, 8.0717330027043772, 1.7486374402258777]

# %%
plt.loglog(numPointsSGpp[3:], errorSGpp[3:] , label="SG++")
plt.loglog(fixedNumPointsTR,fixedErrorTR, label="Only Split TR")
plt.loglog(extend3NumPointsTR,extend3ErrorTR, label="Extend + Split TR")
plt.loglog(standard1NumPointsTR,standard1ErrorTR, label="Standard Combi TR lmin = 1")
plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.6), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerSmallTR.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp[3:], errorSGpp[3:] , label="SG++")
plt.loglog(fixedFENumPointsTR,fixedFEErrorTR, label="Only Split TR")
plt.loglog(extend3FENumPointsTR,extend3FEErrorTR, label="Extend + Split TR")
plt.loglog(standard1FENumPointsTR,standard1FEErrorTR, label="Standard Combi TR lmin = 1")
plt.loglog(standard2FENumPointsTR,standard2FEErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.6), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerSmallFETR.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp[3:], errorSGpp[3:] , label="SG++")
plt.loglog(fixedNumPointsCC,fixedErrorCC, label="Only Split CC")
plt.loglog(extend3NumPointsCC,extend3errorCC, label="Extend + Split CC")
plt.loglog(standard1NumPointsCC,standard1ErrorCC, label="Standard Combi CC lmin = 1")
plt.loglog(standard2NumPointsCC,standard2ErrorCC, label="Standard Combi CC lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.6), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerSmallCC.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp[3:], errorSGpp[3:] , label="SG++")
plt.loglog(fixedFENumPointsCC,fixedFEErrorCC, label="Only Split CC")
plt.loglog(extend3FENumPointsCC,extend3FEerrorCC, label="Extend + Split CC")
plt.loglog(standard1FENumPointsCC,standard1FEErrorCC, label="Standard Combi CC lmin = 1")
plt.loglog(standard2FENumPointsCC,standard2FEErrorCC, label="Standard Combi CC lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.6), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerSmallFECC.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
plt.loglog(fixedNumPointsCC,fixedErrorCC, label="Only Split CC")
plt.loglog(extend3NumPointsCC,extend3errorCC, label="Extend + Split CC")
plt.loglog(fixedNumPointsTR,fixedErrorTR, label="Only Split TR")
plt.loglog(extend3NumPointsTR,extend3ErrorTR, label="Extend + Split TR")
plt.loglog(standard1NumPointsCC,standard1ErrorCC, label="Standard Combi CC lmin = 1")
plt.loglog(standard2NumPointsCC,standard2ErrorCC, label="Standard Combi CC lmin = 2")
plt.loglog(standard1NumPointsTR,standard1ErrorTR, label="Standard Combi TR lmin = 1")
plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.6), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')

# %% [markdown]
# Test corner larger

# %%
a = 0
b = 1
dim = 2
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b, "functionCornerLarger.pdf")

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=ClenshawCurtisGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed Scheme')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,9,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 0.000210824788433
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00103096920726
# combiintegral: -0.000962954329035
# Current error: 0.00117377911747
# Number of refinements 0
# time spent in case
#  1 0.6454980373382568
# time spent in case
#  2 0.05860090255737305
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00103096920726
# combiintegral: -0.000962954329035
# Current error: 0.00117377911747
# Refining position 31
# Finished refinement
# max error:
#  0.000129733726252
# combiintegral: 6.18681832739e-05
# Current error: 0.000148956605159
# Number of refinements 1
# time spent in case
#  3 1.3424570560455322
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=ClenshawCurtisGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,10,dim,0,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 0.000210824788433
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00103096920726
# combiintegral: -0.000962954329035
# Current error: 0.00117377911747
# Number of refinements 0
# time spent in case
#  1 0.6499817371368408
# time spent in case
#  2 0.059502601623535156
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.00103096920726
# combiintegral: -0.000962954329035
# Current error: 0.00117377911747
# Refining position 31
# Finished refinement
# max error:
#  0.000129733726252
# combiintegral: 6.18681832739e-05
# Current error: 0.000148956605159
# Number of refinements 1
# time spent in case
#  3 1.3595736026763916
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=TrapezoidalGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,9,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 0.000210824788433
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.000559684547917
# combiintegral: -0.000432909097108
# Current error: 0.000643733885541
# Number of refinements 0
# time spent in case
#  1 0.45752763748168945
# time spent in case
#  2 0.06937694549560547
# time spent in case
#  3 0.06490397453308105
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.000559684547917
# combiintegral: -0.000432909097108
# Current error: 0.000643733885541
# Refining position 31
# Finished refinement
# max error:
#  7.67143303187e-05
# combiintegral: 0.000120581063546
# Current error: 9.02437248872e-05
# Number of refinements 1
# time spent in case
#  4 0.8188884258270264
# 0 [1, 1, 1, 1, 2] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=TrapezoidalGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,5,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceFixed,1,2,'Fixed Scheme')]
#algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized')]

performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,7,dim,10,grid,1,6)
# Out:
# Cannot plot function with dim > 2
# Exact integral 0.000210824788433
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.000559684547917
# combiintegral: -0.000432909097108
# Current error: 0.000643733885541
# Number of refinements 0
# time spent in case
#  1 0.39993906021118164
# time spent in case
#  2 0.06838631629943848
# time spent in case
#  3 0.06134605407714844
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.000559684547917
# combiintegral: -0.000432909097108
# Current error: 0.000643733885541
# Refining position 31
# Finished refinement
# max error:
#  7.67143303187e-05
# combiintegral: 0.000120581063546
# Current error: 9.02437248872e-05
# Number of refinements 1
# time spent in case
#  4 0.8096849918365479
# 0 [1, 1, 1, 1, 2] 1.0
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.99
coefficients = np.array([ 10**1 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
montecarloNumPoints = []
montecarloError = []
for i in range(8):
    analyticSolution = f.getAnalyticSolutionIntegral(np.ones(dim)* a, np.ones(dim)* b)
    integral = montecarlo(f,10**i,dim)
    montecarloError.append(abs(integral - analyticSolution)/analyticSolution)
    montecarloNumPoints.append(10**i)
    print(10**i,abs(integral - analyticSolution)/analyticSolution)
print("montecarloNumPoints =",montecarloNumPoints)
print("montecarloError =",montecarloError)
# Out:
# 1 0.999999991714
# 10 0.999973156752
# 100 2.80208492885
# 1000 0.834594838047
# 10000
#  0.160289131549
# 100000
#  0.111713338435
# 1000000
#  0.000263748635608
# 10000000
#  0.00795657467786
# montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
fixedNumPointsTR = [2268, 2268, 2268, 4264, 7682, 129221] 
fixedErrorTR = [3.0534070036334171, 3.0534070036334171, 3.0534070036334171, 0.4280508262713702, 0.0070909888908426508, 0.0044311608471682652]
fixedFENumPointsTR = [1053, 1053, 1053, 1994, 3627, 64576] 
fixedFEErrorTR = [3.0534070036334171, 3.0534070036334171, 3.0534070036334171, 0.4280508262713702, 0.0070909888908426508, 0.0044311608471682652]

extend2NumPointsTR = [2268, 2268, 2268, 4264, 7682, 16214, 193422, 962315] 
extend2ErrorTR = [3.0534070036334171, 3.0534070036334171, 3.0534070036334171, 0.4280508262713702, 0.0070909888908426508, 0.00076236950264916485, 0.00023440366335040507, 3.1590013297160974e-05]
extend2FENumPointsTR = [1053, 1053, 1053, 1994, 3627, 7779, 47292, 151800] 
extend2FEErrorTR = [3.0534070036334171, 3.0534070036334171, 3.0534070036334171, 0.4280508262713702, 0.0070909888908426508, 0.00076236950264916485, 0.00023440366335040507, 3.1590013297160974e-05]

standard1NumPointsTR = [2268, 12663, 55098, 206358, 698885, 2202350, 6574845, 18820515]
standard1ErrorTR = [3.0534070036334171, 0.74987576935384959, 0.038447210802425767, 0.007845817690104194, 0.00025264685106777537, 3.4660948669896217e-05, 2.9489682582612295e-06, 4.8677865799709047e-07] 
standard1FENumPointsTR = [1053, 3753, 12033, 36033, 102785, 282625, 754945, 1969665] 
standard1FEErrorTR = [3.0534070036334171, 0.74987576935384959, 0.038447210802425767, 0.007845817690104194, 0.00025264685106777537, 3.4660948669896217e-05, 2.9489682582612295e-06, 4.8677865799709047e-07]

standard2NumPointsTR = [182500, 850375, 3354025]
standard2ErrorTR = [5.9354159459621672, 3.9510401925790073, 0.98866418733901418]
#standard2NumPointsCC = [182500, 850375, 3354025] 
#standard2ErrorCC = [0.65696600753402801, 0.39589203615030161, 0.053447191010177343]
standard1NumPointsCC = [2268, 12663, 55098, 206358, 698885, 2202350]
standard1ErrorCC = [0.25475331864109024, 0.065512433150282448, 0.02276790749611941, 0.0057453188113223133, 0.00092389397557285737, 0.00017984044323422524]
standard1FENumPointsCC = [1053, 3753, 12033, 36033, 102785, 282625, 754945, 1969665] 
standard1FEErrorCC = [0.25475331864109024, 0.065512433150282448, 0.02276790749611941, 0.0057453188113223133, 0.00092389397557285737, 0.00017984044323422524, 1.4240624390478375e-05, 1.5604151529293938e-06]

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedNumPointsCC,fixedErrorCC, label="Only Split CC")
plt.loglog(extend2NumPointsCC,extend2errorCC, label="Extend + Split CC 2")
#plt.loglog(extend1NumPointsCC,extend1errorCC, label="Extend + Split CC 1")
plt.loglog(standard1NumPointsCC,standard1ErrorCC, label="Standard Combi CC lmin = 1")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerLargerCC.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedFENumPointsCC,fixedFEErrorCC, label="Only Split CC")
plt.loglog(extend2FENumPointsCC,extend2FEerrorCC, label="Extend + Split CC 2")
#plt.loglog(extend1NumPointsCC,extend1errorCC, label="Extend + Split CC 1")
plt.loglog(standard1FENumPointsCC,standard1FEErrorCC, label="Standard Combi CC lmin = 1")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerLargerFECC.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedNumPointsTR,fixedErrorTR, label="Only Split TR")
plt.loglog(extend2NumPointsTR,extend2ErrorTR, label="Extend + Split TR")
plt.loglog(standard1NumPointsTR,standard1ErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerLargerTR.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedFENumPointsTR,fixedFEErrorTR, label="Only Split TR")
plt.loglog(extend2FENumPointsTR,extend2FEErrorTR, label="Extend + Split TR")
plt.loglog(standard1FENumPointsTR,standard1FEErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceCornerLargerFETR.pdf', bbox_inches='tight')

# %% [markdown]
# Test Middle of domain

# %%
a = 0
b = 1
dim = 2
midpoints = np.ones(dim) * 0.5
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b,"functionMiddle.pdf")

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.5
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=TrapezoidalGrid(False)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed scheme min=1 max=2')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,8,dim,10,grid,1,5)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.59692330432e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error: 0.00146345393307
# combiintegral: -0.0468145566251
# Current error: 0.0468305258581
# Number of refinements 0
# time spent in case
#  1 0.11534929275512695
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error: 0.00146345393307
# combiintegral: -0.0468145566251
# Current error: 0.0468305258581
# Refining position
#  0
# Refining position 1
# Refining position 2
# Refining position
#  3
# Refining position 4
# Refining position 5
# Refining position
#  6
# Refining position 7
# Refining position 8
# Refining position
#  9
# Refining position 10
# Refining position 11
# Refining position
#  12
# Refining position 13
# Refining position 14
# Refining position
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.5
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=ClenshawCurtisGrid(False)
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
#adaptiveCombiInstanceExtend2 = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,1,grid,False)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,2,grid,False,True)

#adaptiveCombiInstanceExtend.performSpatiallyAdaptiv(1,2,integrator,f,errorOperator,10**-8, plot = False)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2 Optimized'),(adaptiveCombiInstanceFixed,1,2,'Fixed scheme min=1 max=2')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,8,dim,10,grid,1,5)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.59692330432e-05
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error: 0.00227662639791
# combiintegral: -0.0728360755001
# Current error: 0.0728520447331
# Number of refinements 0
# time spent in case
#  1 0.12673401832580566
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error: 0.00227662639791
# combiintegral: -0.0728360755001
# Current error: 0.0728520447331
# Refining position
#  0
# Refining position 1
# Refining position 2
# Refining position
#  3
# Refining position 4
# Refining position 5
# Refining position
#  6
# Refining position 7
# Refining position 8
# Refining position
#  9
# Refining position 10
# Refining position 11
# Refining position
#  12
# Refining position 13
# Refining position 14
# Refining position
# ...

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.5
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
montecarloNumPoints = []
montecarloError = []
for i in range(8):
    analyticSolution = f.getAnalyticSolutionIntegral(np.ones(dim)* a, np.ones(dim)* b)
    integral = montecarlo(f,10**i,dim)
    montecarloError.append(abs(integral - analyticSolution)/analyticSolution)
    montecarloNumPoints.append(10**i)
    print(10**i,abs(integral - analyticSolution)/analyticSolution)
print("montecarloNumPoints =",montecarloNumPoints)
print("montecarloError =",montecarloError)
# Out:
# 1 1.0
# 10 1.0
# 100 0.998839982127
# 1000 0.969223372686
# 10000
#  0.580386423316
# 100000
#  0.22755185264
# 1000000
#  0.0632066099489
# 10000000
#  0.0263584089464
# montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
# montecarloError = [1.0, 1.0, 0.99883998212747971, 0.96922337268564818, 0.58038642331604329, 0.22755185263971689, 0.063206609948933262, 0.02635840894636788]

# %%
a = 0
b = 1
dim = 5
midpoints = np.ones(dim) * 0.5
coefficients = np.array([ 10**2 * (d+1) for d in range(dim)])
f = Function2Jakeman(midpoints,coefficients)
montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
montecarloError = [1.0, 1.0, 0.99883998212747971, 0.96922337268564818, 0.58038642331604329, 0.22755185263971689, 0.063206609948933262, 0.02635840894636788]
numPointsSGpp=[11, 71, 343, 1371, 4787, 14503, 40307, 84229, 134773, 191341, 245205, 296357, 345283, 394537, 444617, 492539, 540693, 589829, 637211, 686175, 733497]
errorSGpp=[2932.55, 236.52, 1236.43, 454.196, 247.755, 207.749, 34.051, 20.4435, 14.4726, 2.50786, 0.672933, 0.445845, 0.744513, 0.292387, 0.292572, 0.0890396, 0.121139, 0.10157, 0.248676, 0.27733, 0.0806055]
numPointsSGpp2 = [1471, 4887, 14603, 40407, 84329, 134873, 191441, 245305, 296457, 345383, 394637, 444717, 492639, 540793, 589929, 637311, 686275, 733597, 782639, 830479, 877705] 
errorSGpp2 = [454.196, 247.755, 207.749, 34.051, 20.4435, 14.4726, 2.50786, 0.672933, 0.445845, 0.744513, 0.292387, 0.292572, 0.0890396, 0.121139, 0.10157, 0.248676, 0.27733, 0.0806055, 0.108138, 0.138429, 0.0841595] 

fixedNumPointsCC = [16, 3078, 32060, 32060, 84976, 122828, 195464] 
fixedErrorCC = [4562.0252729873991, 122.60916904810351, 1.9788328324339783, 1.9788328324339783, 0.40196572613564902, 0.056976535680458629, 0.0032819148740787975]
fixedFENumPointsCC = [11, 1863, 16435, 16435, 43251, 63163, 100239] 
fixedFEErrorCC = [4562.0252729873991, 122.60916904810351, 1.9788328324339783, 1.9788328324339783, 0.40196572613564902, 0.056976535680458629, 0.0032819148740787975]

extend2NumPointsCC = [16, 3078, 32060, 32060, 118353, 118353, 118353]
extend2errorCC =  [4562.0252729873991, 122.60916904810351, 1.9788328324339783, 1.9788328324339783, 0.0051784718968447899, 0.0051784718968447899, 0.0051784718968447899]
extend2FENumPointsCC = [11, 1863, 16435, 16435, 26803, 26803, 26803] 
extend2FEerrorCC = [4562.0252729873991, 122.60916904810351, 1.9788328324339783, 1.9788328324339783, 0.0051784718968447899, 0.0051784718968447899, 0.0051784718968447899]

#extend1NumPointsCC = [8704, 8704, 17136, 25568, 34000, 141264, 1837684, 1846564, 16835102] 
#extend1errorCC = [5.5675574309465761, 5.5675574309465761, 0.7065421778258717, 0.0921150826130578, 0.041161934877707099, 0.00067708826678063909, 0.00042080357350915426, 2.2619533045400088e-05, 7.8381264236687192e-07]
extend2errorTR = [2932.5469627461835, 76.859548638896925, 0.94880351041776012, 0.94880351041776012, 0.18633673283658217, 0.031363326145084122, 0.0057300069226762212] 
extend2FENumPointsTR = [11, 1863, 16435, 16435, 26723, 28775, 90979] 
extend2FEerrorTR = [2932.5469627461835, 76.859548638896925, 0.94880351041776012, 0.94880351041776012, 0.18633673283658217, 0.031363326145084122, 0.0057300069226762212]

fixedNumPointsTR = [16, 3078, 32060, 32060, 61042, 151730, 151730] 
fixedErrorTR = [2932.5469627461835, 76.859548638896925, 0.94880351041776012, 0.94880351041776012, 0.42875262254289492, 0.0054380438381443552, 0.0054380438381443552]
fixedFENumPointsTR = [11, 1863, 16435, 16435, 31007, 77655, 77655] 
fixedFEErrorTR = [2932.5469627461835, 76.859548638896925, 0.94880351041776012, 0.94880351041776012, 0.42875262254289492, 0.0054380438381443552, 0.0054380438381443552]

standard1NumPointsTR = [16, 141, 906, 4746, 21503, 87358, 325943, 1135893]
standard1ErrorTR = [2932.5469627461816, 236.51994686825969, 1236.4340980274505, 454.19604302171138, 247.7550108030278, 207.74921127812675, 34.051041042281952, 20.43398619311623]
standard1FENumPointsTR = [11, 71, 351, 1471, 5503, 18943, 61183, 187903] 
standard1FEErrorTR = [2932.5469627461816, 236.51994686825969, 1236.4340980274505, 454.19604302171138, 247.7550108030278, 207.74921127812675, 34.051041042281952, 20.43398619311623] 

standard2NumPointsTR = [22140, 122265, 560175]
standard2ErrorTR = [352.29917229615791, 258.0857514293059, 64.367269450582995]
#standard2NumPointsCC = [182500, 850375, 3354025] 
#standard2ErrorCC = [0.65696600753402801, 0.39589203615030161, 0.053447191010177343]
standard1NumPointsCC = [16, 141, 906, 4746, 21503, 87358, 325943, 1135893]
standard1ErrorCC = [8247.2852059823654, 7501.0124404640137, 2465.6462638453281, 6029.0295609348814, 2113.7161888601245, 1269.6734894623935, 1540.6510365701054, 576.75267355964706]
standard1FENumPointsCC = [11, 71, 351, 1471, 5503, 18943, 61183, 187903] 
standard1FEErrorCC = [8247.2852059823654, 7501.0124404640137, 2465.6462638453281, 6029.0295609348814, 2113.7161888601245, 1269.6734894623935, 1540.6510365701054, 576.75267355964706]

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedNumPointsCC,fixedErrorCC, label="Only Split CC")
plt.loglog(extend2NumPointsCC,extend2errorCC, label="Extend + Split CC 2")
#plt.loglog(extend1NumPointsCC,extend1errorCC, label="Extend + Split CC 1")
plt.loglog(standard1NumPointsCC,standard1ErrorCC, label="Standard Combi CC lmin = 1")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceMiddleCC.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedFENumPointsCC,fixedFEErrorCC, label="Only Split CC")
plt.loglog(extend2FENumPointsCC,extend2FEerrorCC, label="Extend + Split CC 2")
#plt.loglog(extend1NumPointsCC,extend1errorCC, label="Extend + Split CC 1")
plt.loglog(standard1FENumPointsCC,standard1FEErrorCC, label="Standard Combi CC lmin = 1")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceMiddleFECC.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedNumPointsTR,fixedErrorTR, label="Only Split TR")
plt.loglog(extend2NumPointsTR,extend2errorTR, label="Extend + Split TR")
plt.loglog(standard1NumPointsTR,standard1ErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceMiddleTR.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedFENumPointsTR,fixedFEErrorTR, label="Only Split TR")
plt.loglog(extend2FENumPointsTR,extend2FEerrorTR, label="Extend + Split TR")
plt.loglog(standard1FENumPointsTR,standard1FEErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceMiddleFETR.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(fixedNumPointsTR,fixedErrorTR, label="Only Split TR")
plt.loglog(extend2NumPointsCC,extend2errorCC, label="Extend + Split CC 2")
#plt.loglog(extend1NumPointsCC,extend1errorCC, label="Extend + Split CC 1")
plt.loglog(extend2NumPointsTR,extend2errorTR, label="Extend + Split TR 2")

plt.loglog(standard1NumPointsCC,standard1ErrorCC, label="Standard Combi CC lmin = 1")
#plt.loglog(standard2NumPointsCC,standard2ErrorCC, label="Standard Combi CC lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(3,1), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')

# %% [markdown]
# Function Griebel

# %%
a = 0
b = 1
dim = 2
f = FunctionGriebel()
#f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b, "functionGriebel.pdf")

# %%
a = 0
b = 1
dim = 5
f = FunctionGriebel()
#f = Function2Jakeman(midpoints,coefficients)
f.plot(np.ones(dim)*a,np.ones(dim)*b)
errorOperator=ErrorCalculatorAnalytic()
grid=TrapezoidalGrid()
adaptiveCombiInstanceSingleDim = SpatiallyAdaptivSingleDimensions(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceFixed = SpatiallyAdaptivFixedScheme(np.ones(dim)*a, np.ones(dim)*b,grid)
adaptiveCombiInstanceExtend = SpatiallyAdaptivExtendScheme(np.ones(dim)*a, np.ones(dim)*b,0,grid, noInitialSplitting=False,topDiagIncreaseCoarsening=True)
algorithmArray = [(adaptiveCombiInstanceExtend,1,2,'Extend scheme min=1 max=2')]
performTestcaseArbitraryDim(f,a*np.ones(dim),b*np.ones(dim),algorithmArray,errorOperator,3,dim,11,grid,1,5)
# Out:
# Cannot plot function with dim > 2
# Exact integral 1.0
# 0 [1, 1, 1, 1, 2] 1.0
# 1 [1, 1, 1, 2, 1] 1.0
# 2 [1, 1, 2, 1, 1] 1.0
# 3 [1, 2, 1, 1, 1] 1.0
# 4 [2, 1, 1, 1, 1] 1.0
# 5 [1, 1, 1, 1, 1] -4.0
# max error:
#  0.000872869758357
# combiintegral: 0.60335006326
# Current error: 0.39664993674
# Refining position 1
# New scheme
# 0 [1, 1, 1, 1, 3] 1.0
# 1 [1, 1, 1, 2, 2] 1.0
# 2 [1, 1, 1, 3, 1] 1.0
# 3 [1, 1, 2, 1, 2] 1.0
# 4 [1, 1, 2, 2, 1] 1.0
# 5 [1, 1, 3, 1, 1] 1.0
# 6 [1, 2, 1, 1, 2] 1.0
# 7 [1, 2, 1, 2, 1] 1.0
# 8 [1, 2, 2, 1, 1] 1.0
# 9 [1, 3, 1, 1, 1] 1.0
# 10 [2, 1, 1, 1, 2] 1.0
# 11 [2, 1, 1, 2, 1] 1.0
# 12 [2, 1, 2, 1, 1] 1.0
# 13 [2, 2, 1, 1, 1] 1.0
# 14 [3, 1, 1, 1, 1] 1.0
# 15 [1, 1, 1, 1, 2] -4.0
# 16 [1, 1, 1, 2, 1] -4.0
# 17 [1, 1, 2, 1, 1] -4.0
# 18 [1, 2, 1, 1, 1] -4.0
# 19 [2, 1, 1, 1, 1] -4.0
# 20 [1, 1, 1, 1, 1] 6.0
# Finished refinement
# max error: 0.0144023510129
# combiintegral: 0.607252595266
# Current error: 0.392747404734
# Refining position
#  1
# ...

# %%
a = 0
b = 1
dim = 5
f = FunctionGriebel()
montecarloNumPoints = []
montecarloError = []
analyticSolution = f.getAnalyticSolutionIntegral(np.ones(dim)* a, np.ones(dim)* b)
print(analyticSolution)
for i in range(8):
    analyticSolution = f.getAnalyticSolutionIntegral(np.ones(dim)* a, np.ones(dim)* b)
    integral = montecarlo(f,10**i,dim)
    montecarloError.append(abs(integral - analyticSolution)/analyticSolution)
    montecarloNumPoints.append(10**i)
    print(10**i,abs(integral - analyticSolution)/analyticSolution)
print("montecarloNumPoints =",montecarloNumPoints)
print("montecarloError =",montecarloError)
# Out:
# 1.0
# 1 0.243628193395
# 10 0.175149620111
# 100 0.0184350739371
# 1000 0.00794446957888
# 10000 0.00261891846616
# 100000
#  4.66372099837e-05
# 1000000
#  0.000634506738256
# 10000000
#  1.67400442863e-05
# montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
# montecarloError = [0.2436281933949157, 0.17514962011110335, 0.018435073937140389, 0.0079444695788786213, 0.0026189184661613574, 4.6637209983657613e-05, 0.00063450673825571346, 1.6740044286311928e-05]

# %%
montecarloNumPoints = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
montecarloError = [0.11201221234803849, 0.25814929167027467, 0.01656156406602971, 0.0088697539915842949, 0.0012678848995493208, 0.0012745644889924357, 0.00014769786420465447, 2.7000960179046629e-05]
numPointsSGpp = [1053, 3753, 12033, 35978, 100234, 222282, 359462, 500977, 640127, 794343, 912573, 1033052, 1167376, 1311102, 1444531, 1580815, 1697221, 1813093, 1948495, 2069863, 2110495, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815, 2110815] 
errorSGpp = [0.39665, 0.241177, 0.141781, 0.0811563, 0.0454558, 0.0250091, 0.0135831, 0.00733008, 0.00396604, 0.00218747, 0.00124002, 0.000739998, 0.000502863, 0.000357469, 0.000282307, 0.000249592, 0.000214212, 0.000198165, 0.00018705, 0.000162909, 0.000161652, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645, 0.000161645]


standard1NumPointsTR = [2268, 12663, 55098, 206358, 698885, 2202350, 6574845, 18820515, 52092630] 
standard1ErrorTR = [0.39664993674035243, 0.24117696974421454, 0.14178115546758496, 0.081156333891181598, 0.045455526761725817, 0.025001916179049233, 0.013541405795246764, 0.0072373109572663186, 0.0038233606527149355]
standard1FENumPointsTR = [1053, 3753, 12033, 36033, 102785, 282625, 754945, 1969665, 5039105] 
standard1FEErrorTR = [0.39664993674035243, 0.24117696974421454, 0.14178115546758496, 0.081156333891181598, 0.045455526761725817, 0.025001916179049233, 0.013541405795246764, 0.0072373109572663186, 0.0038233606527149355]
extend0NumPointsTR = [199428, 16787085] 
extend0errorTR = [0.086183998001518547, 0.0086381318384615158] 
extend0FENumPointsTR = [33978, 1596335] 
extend0FEerrorTR = [0.086183998001518547, 0.0086381318384615158]

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(extend0NumPointsTR,extend0errorTR, label="Extend + Split TR")
plt.loglog(standard1NumPointsTR,standard1ErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.43), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceGriebel.pdf', bbox_inches='tight')

# %%
plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(extend0FENumPointsTR,extend0errorTR, label="Extend + Split TR")
plt.loglog(standard1FENumPointsTR,standard1ErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
#plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.43), loc="upper right")
plt.xlabel('Necessary function evaluations')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceGriebelFE.pdf', bbox_inches='tight')

# %%
#plt.loglog(numPointsSGpp, errorSGpp , label="SG++")
#plt.loglog(numPointsSGpp2, errorSGpp2 , label="SG++2")

plt.loglog(extend0FENumPointsTR,extend0FEerrorTR, label="Extend + Split TR")
plt.loglog(standard1FENumPointsTR,standard1FEErrorTR, label="Standard Combi TR lmin = 1")
#plt.loglog(standard2NumPointsTR,standard2ErrorTR, label="Standard Combi TR lmin = 2")
plt.loglog(montecarloNumPoints[3:],montecarloError[3:], label="Monte Carlo")

plt.legend(bbox_to_anchor=(0.8,1.5), loc="upper right")
plt.xlabel('Number of points')
plt.ylabel('Approximation error (rel)')
plt.savefig('convergenceGriebel.pdf', bbox_inches='tight')

# %%
a = 0
b = 1
dim = 5
f = FunctionGriebel()
numPointsSGpp=
errorSGpp=
